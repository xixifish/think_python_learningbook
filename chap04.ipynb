# %% [markdown]
# <a href="https://colab.research.google.com/github/xixifish/think_python_learningbook/blob/main/chap04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
make_turtle()
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,200.0,25.0) translate(200.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="180.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="45.0" x2="150.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="15.0" x2="150.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.02)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="152.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.1" y1="75.0" x2="154.1" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.1" y1="74.6" x2="156.1" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.1" y1="73.7" x2="157.8" y2="72.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.8" y1="72.5" x2="159.2" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.2" y1="70.9" x2="160.2" y2="69.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.2" y1="69.1" x2="160.8" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.8" y1="67.1" x2="161.1" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.1" y1="65.0" x2="160.8" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.8" y1="63.0" x2="160.2" y2="61.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.2" y1="61.0" x2="159.2" y2="59.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.2" y1="59.1" x2="157.8" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.8" y1="57.6" x2="156.1" y2="56.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.1" y1="56.4" x2="154.1" y2="55.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.1" y1="55.5" x2="152.1" y2="55.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.1" y1="55.1" x2="150.0" y2="55.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="55.1" x2="148.0" y2="55.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="55.5" x2="146.0" y2="56.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="56.4" x2="144.3" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.3" y1="57.6" x2="142.9" y2="59.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.9" y1="59.1" x2="141.9" y2="61.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.9" y1="61.0" x2="141.2" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="63.0" x2="141.0" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.0" y1="65.0" x2="141.2" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="67.1" x2="141.9" y2="69.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.9" y1="69.1" x2="142.9" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.9" y1="70.9" x2="144.3" y2="72.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.3" y1="72.5" x2="146.0" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="73.7" x2="148.0" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="74.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
import math

def rectangle(bottom, tall):

  forward(bottom)

  # angle_first_in_radians = math.atan2(tall, bottom / 2)
  # angle_first_in_degrees = math.degrees(angle_first_in_radians)
  # left(180 - angle_first_in_degrees)
  left(90)

  # side = math.sqrt(tall ** 2 + (bottom / 2) ** 2)
  # forward(side)
  forward(tall)

  # angle_second_in_degrees = 180 - angle_first_in_degrees * 2
  # left(180 - angle_second_in_degrees)
  left(90)
  forward(bottom)

  left(90)
  forward(tall)

  left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):

  # Draw the first line
  forward(length)
  left(180 - angle)

  # Draw the second line
  forward(length)
  left(angle)

  # Draw the third line
  forward(length)
  left(180 - angle)

  # Draw the last line
  forward(length)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="125.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(side_1, side_2, angle):

  # Draw the first line
  forward(side_1)
  left(180 - angle)

  # Draw the second line
  forward(side_2)
  left(angle)

  # Draw the third line
  forward(side_1)
  left(180 - angle)

  # Draw the last line
  forward(side_2)
  left(angle)

# %%
def rectangle(side_1, side_2):
  parallelogram(side_1, side_2, angle=90)

# %%
def rhombus(side, angle):
  parallelogram(side, side, angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=500, height=300)
jump(-200)

rectangle(80, 40)
jump(160)
rhombus(50, 60)
jump(100)
parallelogram(80, 50, 60)
# Out:
# <svg width="500" height="300">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="50.0" y1="150.0" x2="130.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="150.0" x2="130.0" y2="110.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="110.0" x2="50.0" y2="110.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="110.0" x2="50.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="150.0" x2="260.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="150.0" x2="235.0" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.0" y1="106.7" x2="185.0" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="106.7" x2="210.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="310.0" y1="150.0" x2="390.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="390.0" y1="150.0" x2="365.0" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="365.0" y1="106.7" x2="285.0" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.0" y1="106.7" x2="310.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,310.0,150.0) translate(310.0, 150.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
import math

def triangle(side, angle):

  base = 2 * side * math.cos(math.radians(angle))

  # Draw the first line
  forward(side)
  left(180 - angle)

  # Draw the second line
  forward(base)
  left(180 - angle)

  # Draw the last line
  forward(side)

# %%
make_turtle(width=300, height=150)
jump(0)
triangle(40, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150.0" y1="75.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def draw_pie(n, size):
  angle = 360.0 / n
  angle_triangle = (180 - angle) / 2
  for i in range(n):
    triangle(size, angle_triangle)
    right(180)

# %%
make_turtle(width=500, height=500)
jump(-100)
draw_pie(5, 40)
# Out:
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150.0" y1="250.0" x2="190.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="250.0" x2="162.4" y2="212.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="212.0" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="162.4" y2="212.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="212.0" x2="117.6" y2="226.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.6" y1="226.5" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="117.6" y2="226.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.6" y1="226.5" x2="117.6" y2="273.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.6" y1="273.5" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="117.6" y2="273.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.6" y1="273.5" x2="162.4" y2="288.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="288.0" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="250.0" x2="162.4" y2="288.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="288.0" x2="190.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="250.0" x2="150.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,250.0) translate(150.0, 250.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# You can use the following code to test your functions.

# %%
turtle = make_turtle(delay=0)
jump(-100)

size = 40
draw_pie(5, size)
jump(2*size + 10)
draw_pie(6, size)
jump(2*size + 10)
draw_pie(7, size)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="50.0" y1="75.0" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="62.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="62.4" y1="37.0" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="75.0" x2="62.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="62.4" y1="37.0" x2="17.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="17.6" y1="51.5" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="75.0" x2="17.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="17.6" y1="51.5" x2="17.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="17.6" y1="98.5" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="75.0" x2="17.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="17.6" y1="98.5" x2="62.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="62.4" y1="113.0" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="75.0" x2="62.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="62.4" y1="113.0" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="160.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="40.4" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="160.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="40.4" x2="120.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="40.4" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="120.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="40.4" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="120.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="109.6" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="120.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.0" y1="109.6" x2="160.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="109.6" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="75.0" x2="160.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="109.6" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="140.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def petal(radius, angle):
  arc(radius, angle)
  left(180 - angle)
  arc(radius, angle)
  left(180)

# %%
make_turtle(width=200, height=200, delay=0)
jump(0)
petal(60, 60)
# Out:
# <svg width="200" height="200">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="100.0" y1="100.0" x2="102.1" y2="100.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="100.0" x2="104.2" y2="99.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.2" y1="99.9" x2="106.3" y2="99.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.3" y1="99.8" x2="108.4" y2="99.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.4" y1="99.6" x2="110.4" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.4" y1="99.3" x2="112.5" y2="98.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.5" y1="98.9" x2="114.5" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.5" y1="98.5" x2="116.6" y2="98.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.6" y1="98.0" x2="118.6" y2="97.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.6" y1="97.4" x2="120.6" y2="96.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.6" y1="96.7" x2="122.6" y2="96.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.6" y1="96.0" x2="124.5" y2="95.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.5" y1="95.2" x2="126.4" y2="94.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.4" y1="94.4" x2="128.3" y2="93.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.3" y1="93.5" x2="130.1" y2="92.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.1" y1="92.5" x2="132.0" y2="91.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="91.4" x2="133.7" y2="90.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.7" y1="90.3" x2="135.5" y2="89.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.5" y1="89.2" x2="137.2" y2="87.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.2" y1="87.9" x2="138.8" y2="86.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.8" y1="86.6" x2="140.4" y2="85.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.4" y1="85.3" x2="142.0" y2="83.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="83.9" x2="143.5" y2="82.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.5" y1="82.4" x2="144.9" y2="80.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.9" y1="80.9" x2="146.3" y2="79.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.3" y1="79.4" x2="147.7" y2="77.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.7" y1="77.8" x2="149.0" y2="76.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.0" y1="76.1" x2="150.2" y2="74.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.2" y1="74.4" x2="151.4" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="72.7" x2="152.5" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.5" y1="70.9" x2="150.4" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.4" y1="70.9" x2="148.3" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.3" y1="71.0" x2="146.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.2" y1="71.1" x2="144.1" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.1" y1="71.3" x2="142.0" y2="71.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="71.6" x2="140.0" y2="72.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="72.0" x2="137.9" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.9" y1="72.4" x2="135.9" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="72.9" x2="133.9" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.9" y1="73.5" x2="131.9" y2="74.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.9" y1="74.2" x2="129.9" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.9" y1="74.9" x2="128.0" y2="75.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="75.7" x2="126.1" y2="76.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="76.5" x2="124.2" y2="77.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.2" y1="77.4" x2="122.3" y2="78.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.3" y1="78.4" x2="120.5" y2="79.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.5" y1="79.5" x2="118.8" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.8" y1="80.6" x2="117.0" y2="81.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.0" y1="81.8" x2="115.3" y2="83.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.3" y1="83.0" x2="113.7" y2="84.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.7" y1="84.3" x2="112.1" y2="85.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.1" y1="85.6" x2="110.5" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="87.0" x2="109.0" y2="88.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="88.5" x2="107.5" y2="90.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.5" y1="90.0" x2="106.1" y2="91.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.1" y1="91.5" x2="104.8" y2="93.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.8" y1="93.1" x2="103.5" y2="94.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.5" y1="94.8" x2="102.3" y2="96.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.3" y1="96.5" x2="101.1" y2="98.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.1" y1="98.2" x2="100.0" y2="100.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(210.0,100.0,100.0) translate(100.0, 100.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def flower(n ,radius, angle):
  angle_center = 360 / n
  for i in range(n):
    petal(radius, angle)
    left(-angle)
    left(angle_center)

# %%
make_turtle(width=500, height=500, delay=0)
jump(0)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)
# Out:
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250.0" y1="250.0" x2="252.1" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.1" y1="250.0" x2="254.2" y2="249.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.2" y1="249.9" x2="256.3" y2="249.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="256.3" y1="249.8" x2="258.4" y2="249.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="258.4" y1="249.6" x2="260.4" y2="249.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.4" y1="249.3" x2="262.5" y2="248.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.5" y1="248.9" x2="264.5" y2="248.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.5" y1="248.5" x2="266.6" y2="248.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.6" y1="248.0" x2="268.6" y2="247.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="268.6" y1="247.4" x2="270.6" y2="246.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.6" y1="246.7" x2="272.6" y2="246.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="272.6" y1="246.0" x2="274.5" y2="245.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.5" y1="245.2" x2="276.4" y2="244.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="276.4" y1="244.4" x2="278.3" y2="243.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.3" y1="243.5" x2="280.1" y2="242.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="280.1" y1="242.5" x2="282.0" y2="241.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="282.0" y1="241.4" x2="283.7" y2="240.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.7" y1="240.3" x2="285.5" y2="239.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.5" y1="239.2" x2="287.2" y2="237.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.2" y1="237.9" x2="288.8" y2="236.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="288.8" y1="236.6" x2="290.4" y2="235.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.4" y1="235.3" x2="292.0" y2="233.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.0" y1="233.9" x2="293.5" y2="232.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="293.5" y1="232.4" x2="294.9" y2="230.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.9" y1="230.9" x2="296.3" y2="229.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.3" y1="229.4" x2="297.7" y2="227.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.7" y1="227.8" x2="299.0" y2="226.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="299.0" y1="226.1" x2="300.2" y2="224.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.2" y1="224.4" x2="301.4" y2="222.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.4" y1="222.7" x2="302.5" y2="220.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.5" y1="220.9" x2="300.4" y2="220.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="300.4" y1="220.9" x2="298.3" y2="221.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.3" y1="221.0" x2="296.2" y2="221.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.2" y1="221.1" x2="294.1" y2="221.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.1" y1="221.3" x2="292.0" y2="221.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="292.0" y1="221.6" x2="290.0" y2="222.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.0" y1="222.0" x2="287.9" y2="222.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="287.9" y1="222.4" x2="285.9" y2="222.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.9" y1="222.9" x2="283.9" y2="223.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.9" y1="223.5" x2="281.9" y2="224.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="281.9" y1="224.2" x2="279.9" y2="224.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="279.9" y1="224.9" x2="278.0" y2="225.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.0" y1="225.7" x2="276.1" y2="226.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="276.1" y1="226.5" x2="274.2" y2="227.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.2" y1="227.4" x2="272.3" y2="228.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="272.3" y1="228.4" x2="270.5" y2="229.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.5" y1="229.5" x2="268.8" y2="230.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="268.8" y1="230.6" x2="267.0" y2="231.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="267.0" y1="231.8" x2="265.3" y2="233.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="265.3" y1="233.0" x2="263.7" y2="234.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.7" y1="234.3" x2="262.1" y2="235.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.1" y1="235.6" x2="260.5" y2="237.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.5" y1="237.0" x2="259.0" y2="238.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.0" y1="238.5" x2="257.5" y2="240.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.5" y1="240.0" x2="256.1" y2="241.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="256.1" y1="241.5" x2="254.8" y2="243.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.8" y1="243.1" x2="253.5" y2="244.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.5" y1="244.8" x2="252.3" y2="246.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.3" y1="246.5" x2="251.1" y2="248.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="251.1" y1="248.2" x2="250.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="250.0" y1="250.0" x2="251.3" y2="248.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="251.3" y1="248.4" x2="252.6" y2="246.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.6" y1="246.7" x2="253.7" y2="245.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.7" y1="245.0" x2="254.9" y2="243.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="243.2" x2="255.9" y2="241.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.9" y1="241.4" x2="256.9" y2="239.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="256.9" y1="239.5" x2="257.9" y2="237.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="257.9" y1="237.7" x2="258.7" y2="235.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="258.7" y1="235.8" x2="259.5" y2="233.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.5" y1="233.8" x2="260.3" y2="231.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.3" y1="231.9" x2="261.0" y2="229.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.0" y1="229.9" x2="261.5" y2="227.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.5" y1="227.9" x2="262.1" y2="225.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.1" y1="225.9" x2="262.5" y2="223.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.5" y1="223.8" x2="262.9" y2="221.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.9" y1="221.8" x2="263.2" y2="219.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.2" y1="219.7" x2="263.5" y2="217.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.5" y1="217.6" x2="263.6" y2="215.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.6" y1="215.5" x2="263.7" y2="213.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.7" y1="213.4" x2="263.7" y2="211.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.7" y1="211.3" x2="263.7" y2="209.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.7" y1="209.2" x2="263.6" y2="207.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.6" y1="207.1" x2="263.4" y2="205.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.4" y1="205.1" x2="263.1" y2="203.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="263.1" y1="203.0" x2="262.8" y2="200.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.8" y1="200.9" x2="262.3" y2="198.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="262.3" y1="198.9" x2="261.9" y2="196.8"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

turtle = make_turtle(auto_render=False)

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)

render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="90.0" y1="75.0" x2="92.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.1" y1="75.0" x2="94.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.2" y1="74.9" x2="96.3" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.3" y1="74.8" x2="98.4" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.4" y1="74.6" x2="100.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.4" y1="74.3" x2="102.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.5" y1="73.9" x2="104.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.5" y1="73.5" x2="106.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.6" y1="73.0" x2="108.6" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.6" y1="72.4" x2="110.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.6" y1="71.7" x2="112.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.6" y1="71.0" x2="114.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.5" y1="70.2" x2="116.4" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.4" y1="69.4" x2="118.3" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.3" y1="68.5" x2="120.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.1" y1="67.5" x2="122.0" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="66.4" x2="123.7" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="65.3" x2="125.5" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.5" y1="64.2" x2="127.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.2" y1="62.9" x2="128.8" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="61.6" x2="130.4" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.4" y1="60.3" x2="132.0" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="58.9" x2="133.5" y2="57.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.5" y1="57.4" x2="134.9" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.9" y1="55.9" x2="136.3" y2="54.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.3" y1="54.4" x2="137.7" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.7" y1="52.8" x2="139.0" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.0" y1="51.1" x2="140.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.2" y1="49.4" x2="141.4" y2="47.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="47.7" x2="142.5" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.5" y1="45.9" x2="140.4" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.4" y1="45.9" x2="138.3" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.3" y1="46.0" x2="136.2" y2="46.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.2" y1="46.1" x2="134.1" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.1" y1="46.3" x2="132.0" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="46.6" x2="130.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="47.0" x2="127.9" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.9" y1="47.4" x2="125.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.9" y1="47.9" x2="123.9" y2="48.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.9" y1="48.5" x2="121.9" y2="49.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.9" y1="49.2" x2="119.9" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.9" y1="49.9" x2="118.0" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.0" y1="50.7" x2="116.1" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.1" y1="51.5" x2="114.2" y2="52.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.2" y1="52.4" x2="112.3" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.3" y1="53.4" x2="110.5" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="54.5" x2="108.8" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.8" y1="55.6" x2="107.0" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.0" y1="56.8" x2="105.3" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.3" y1="58.0" x2="103.7" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="59.3" x2="102.1" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="60.6" x2="100.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.5" y1="62.0" x2="99.0" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.0" y1="63.5" x2="97.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.5" y1="65.0" x2="96.1" y2="66.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.1" y1="66.5" x2="94.8" y2="68.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.8" y1="68.1" x2="93.5" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="69.8" x2="92.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.3" y1="71.5" x2="91.1" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.1" y1="73.2" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="91.3" y2="73.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.3" y1="73.4" x2="92.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.6" y1="71.7" x2="93.7" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.7" y1="70.0" x2="94.9" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.9" y1="68.2" x2="95.9" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.9" y1="66.4" x2="96.9" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.9" y1="64.5" x2="97.9" y2="62.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.9" y1="62.7" x2="98.7" y2="60.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.7" y1="60.8" x2="99.5" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.5" y1="58.8" x2="100.3" y2="56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.3" y1="56.9" x2="101.0" y2="54.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.0" y1="54.9" x2="101.5" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.5" y1="52.9" x2="102.1" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="50.9" x2="102.5" y2="48.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.5" y1="48.8" x2="102.9" y2="46.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.9" y1="46.8" x2="103.2" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.2" y1="44.7" x2="103.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.5" y1="42.6" x2="103.6" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.6" y1="40.5" x2="103.7" y2="38.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="38.4" x2="103.7" y2="36.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="36.3" x2="103.7" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="34.2" x2="103.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.6" y1="32.1" x2="103.4" y2="30.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.4" y1="30.1" x2="103.1" y2="28.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.1" y1="28.0" x2="102.8" y2="25.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.8" y1="25.9" x2="102.3" y2="23.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.3" y1="23.9" x2="101.9" y2="21.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.9" y1="21.8" x2="101.3" y2="19.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.3" y1="19.8" x2="100.7" y2="17.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.7" y1="17.8" x2="100.

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
from jupyturtle import make_turtle, forward, left
import math

def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

make_turtle(delay=0)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
